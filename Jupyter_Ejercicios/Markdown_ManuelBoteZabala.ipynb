# %% [markdown]
# # Encabezado de Nivel 1
#
# ## Encabezado de Nivel 2
#
# ### Encabezado de Nivel 3
#
# #### Encabezado de Nivel 4
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. *Texto en itálica* para enfatizar una idea, y **texto en negrita** para destacar información importante.
#
# Este es un párrafo.
# Aquí hay **un salto de línea forzado** (usando dos espacios al final de la línea).
# Y aquí continúa el mismo párrafo con un salto suave.
#
# ## Enlaces
#
# ### Enlace en línea:
#
# Puedes visitar [Google](https://www.google.com).
#
# ### Enlace de referencia:
#
# Esto es una referencia a [Google][1].
#
# [1]: https://www.google.com
#
# ## Imágenes
#
# ### Imagen en línea:
#
# ![Gato curioso](https://placekitten.com/300/200)
#
# ### Imagen con referencia:
#
# ![Perro feliz][perro]
#
# [perro]: https://placedog.net/400
#
# ## Citas importantes
#
# > “No existen errores, solo descubrimientos inesperados.”
# > — Desarrollador Anónimo
#
# ## Lista ordenada
#
# 1. Iniciar sesión
# 2. Seleccionar archivo
# 3. Enviar formulario
#    1. Verificar datos
#    2. Confirmar envío
#
# ## Lista desordenada
#
# - Peras
# - Manzanas
#   - Verdes
#   - Rojas
# - Plátanos
# - Uvas
#
# ## Más párrafos
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer nec odio.
#
# Praesent libero. Sed cursus ante dapibus diam. Sed nisi. Nulla quis sem at nibh elementum imperdiet.
