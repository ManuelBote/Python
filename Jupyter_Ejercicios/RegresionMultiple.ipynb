# %% [markdown]
# # Regresion Multiple entre varias variables

# %% [markdown]
# ## Peso de una persona, pulso cardíaco de una persona y colesterol de una persona.

# %%
import pandas as pd

df = pd.read_csv("persona.csv")

print(df)
# Out:
#      Peso   Pulso  Colesterol
# 0   80.32  107.35      184.43
# 1   73.71  101.76      178.11
# 2   93.99  119.09      215.47
# 3   61.43   87.86      176.28
# 4   59.34   85.70      170.98
# 5   79.67  107.26      189.59
# 6   67.34   95.83      176.18
# 7   94.26  118.65      210.79
# 8   70.01   98.83      178.37
# 9   95.47  119.23      214.35
# 10  78.60  106.62      187.68
# 11  93.21  118.40      212.58
# 12  62.60   88.77      173.57
# 13  70.47   99.11      181.79
# 14  60.74   86.41      172.91
# 15  72.86  100.08      182.62
# 16  85.28  111.66      198.87
# 17  59.06   84.76      168.72
# 18  66.52   95.06      174.86
# 19  93.40  118.47      212.69
# 20  91.85  117.52      209.84
# 21  69.76   98.06      178.33
# 22  90.16  116.84      208.42
# 23  76.69  104.82      184.13
# 24  90.65  116.95      208.57
# 25  80.90  107.64      190.43
# 26  68.21   96.94      176.34
# 27  82.07  108.45      191.37
# 28  89.69  116.39      207.49
# 29  81.73  107.96      189.85
# ...

# %%
X = df[['Peso', 'Pulso']]
y = df['Colesterol']

print("Valores de la variable independiente:")
print(X)
print("Valores de la variable dependiente:")
print(y)
# Out:
# Valores de la variable independiente:
#      Peso   Pulso
# 0   80.32  107.35
# 1   73.71  101.76
# 2   93.99  119.09
# 3   61.43   87.86
# 4   59.34   85.70
# 5   79.67  107.26
# 6   67.34   95.83
# 7   94.26  118.65
# 8   70.01   98.83
# 9   95.47  119.23
# 10  78.60  106.62
# 11  93.21  118.40
# 12  62.60   88.77
# 13  70.47   99.11
# 14  60.74   86.41
# 15  72.86  100.08
# 16  85.28  111.66
# 17  59.06   84.76
# 18  66.52   95.06
# 19  93.40  118.47
# 20  91.85  117.52
# 21  69.76   98.06
# 22  90.16  116.84
# 23  76.69  104.82
# 24  90.65  116.95
# 25  80.90  107.64
# 26  68.21   96.94
# 27  82.07  108.45
# 28  89.69  116.39
# 29  81.73  107.96
# 30  62.71   88.94
# 31  56.74   83.34
# 32  94.10  118.88
# 33  76.13  104.44
# 34  85.45  111.85
# 35  79.25  106.99
# 36  79.38  107.07
# 37  75.54  103.85
# 38  84.46  110.51
# 39  81.13  107.26
# 40  63.29   89.27
# 41  90.32  116.93
# 42  76.56  104.71
# 43  71.09   99.51
# 44  88.35  115.71
# 45  67.39   95.94
# 46  72.31   99.61
# ...

# %%
from sklearn import linear_model

regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression()

# %%
predictedColesterol = regr.predict([[85, 100]])
print("El colesterol de una persona de 85kg de peso y 100 pulsaciones/min es:", predictedColesterol)
# Out:
# El colesterol de una persona de 85kg de peso y 100 pulsaciones/min es: [219.36865501]
# c:\Users\Administrador\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ##  Número de coches en una ciudad, velocidad máxima permitida en una ciudad y número de accidentes por año en una ciudad.

# %%
df = pd.read_csv("vehiculos.csv")

print(df)
# Out:
#     coches  vMax  accidentes
# 0     7500    50          85
# 1    12000    60         120
# 2    25000    50         160
# 3    18000    60         150
# 4    32000    40         220
# 5    35000    60         180
# 6     9000    50          95
# 7    50000    30         250
# 8    45000    40         240
# 9    28000    50         200
# 10   55000    30         270
# 11   15000    60         130
# 12   35000    40         215
# 13   20000    60         160
# 14   16000    50         110
# 15   30000    50         190
# 16   10000    50         105
# 17   40000    40         230
# 18   24000    60         180
# 19   38000    50         220
# 20    7000    50          75
# 21   11000    60         110
# 22   27000    50         185
# 23   36000    30         250
# 24   21000    60         170
# 25   33000    40         210
# 26   22000    50         175
# 27   41000    30         260
# 28    5000    70          50
# 29   26000    50         190
# 30   45000    40         230
# ...

# %%
X = df[['coches', 'vMax']]
y = df['accidentes']

print("Valores de la variable independiente:")
print(X)
print("Valores de la variable dependiente:")
print(y)
# Out:
# Valores de la variable independiente:
#     coches  vMax
# 0     7500    50
# 1    12000    60
# 2    25000    50
# 3    18000    60
# 4    32000    40
# 5    35000    60
# 6     9000    50
# 7    50000    30
# 8    45000    40
# 9    28000    50
# 10   55000    30
# 11   15000    60
# 12   35000    40
# 13   20000    60
# 14   16000    50
# 15   30000    50
# 16   10000    50
# 17   40000    40
# 18   24000    60
# 19   38000    50
# 20    7000    50
# 21   11000    60
# 22   27000    50
# 23   36000    30
# 24   21000    60
# 25   33000    40
# 26   22000    50
# 27   41000    30
# 28    5000    70
# 29   26000    50
# 30   45000    40
# 31   38000    50
# 32   60000    30
# 33   25000    50
# 34   29000    60
# 35   13000    60
# 36   31000    40
# 37   24000    60
# 38   30000    50
# 39   47000    30
# 40   20000    50
# 41   32000    40
# 42   15000    60
# 43    5000    60
# 44   18000    50
# 45   35000    40
# 46   33000    60
# 47   22000    50
# 48   55000    30
# ...

# %%
regr2 = linear_model.LinearRegression()
regr2.fit(X, y)
# Out:
# LinearRegression()

# %%
predictedAccidentes = regr2.predict([[10000, 80]])
print("El numero de accidentes en una ciudad con 10000 coches y una velocidad maxima de 80km/h son:", predictedColesterol)
# Out:
# El numero de accidentes en una ciudad con 10000 coches y una velocidad maxima de 80km/h son: [219.36865501]
# c:\Users\Administrador\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
